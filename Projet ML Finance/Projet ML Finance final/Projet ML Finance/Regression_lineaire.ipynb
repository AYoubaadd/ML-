# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
sns.set()

# %%
data=pd.read_csv("financials.csv")
data = data.dropna()
data.isnull().sum()
# Out:
# Symbol            0
# Name              0
# Sector            0
# Price             0
# Price/Earnings    0
# Dividend Yield    0
# Earnings/Share    0
# 52 Week Low       0
# 52 Week High      0
# Market Cap        0
# EBITDA            0
# Price/Sales       0
# Price/Book        0
# SEC Filings       0
# dtype: int64

# %%
X=data['Price']
Y=data['Price/Earnings']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2 ,random_state=365)
X_train_m =X_train.values.reshape(-1,1)
Y_train_m =Y_train.values.reshape(-1,1)
X_test_m =X_test.values.reshape(-1,1)
Y_test_m =Y_test.values.reshape(-1,1)

# %%
reg=LinearRegression()
reg.fit(X_train_m,Y_train_m)
# Out:
# LinearRegression()

# %%
Y_pred=reg.predict(X_test_m)

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,Y_pred,color='blue')
plt.title('evolotion de prix par taille')
# Out:
# Text(0.5, 1.0, 'evolotion de prix par taille')

# %%
reg.score(X_train_m,Y_train_m)
# Out:
# 0.03859085345312996

# %%
len(X_test)
# Out:
# 99

# %%
len(X_train)
# Out:
# 396

# %%
reg.intercept_
# Out:
# array([18.88125509])

# %%
reg.coef_
# Out:
# array([[0.06022292]])
